# %%
import anndata as an
import scanpy as sc

# %% [markdown]
# ## Import Data

# %%
data = an.read_h5ad("/opt/andrew/lupus/Lupus_Neighbors_10N_3R.h5ad")

# %%
sc.pp.highly_variable_genes(data, min_mean=0.0001, max_mean=10, min_disp=0.01)
data = data[:, data.var.highly_variable.values]
print(data)
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# View of AnnData object with n_obs × n_vars = 1263673 × 1265
# ...

# %%
# data.write_h5ad("LupusHVGNew.h5ad")
! cellxgene launch /opt/pf2/lupus/lupus_fitted_ann.h5ad --open
# cellxgene launch Lupus_Neighbors_10N_3R.h5ad --open
#! cellxgene launch /home/brianoj/scCP/Lupus_Annotated_Final_Updated.h5ad --open
# Out:
# [cellxgene] Starting the CLI...
# [cellxgene] Loading data from Lupus_Annotated_Final_Updated.h5ad, this may take a while...
# [cellxgene] Warning: Anndata data matrix is sparse, but not a CSC (columnar) matrix.  Performance may be improved by using CSC.
# WARNING:root:Type float64 will be converted to 32 bit float and may lose precision.
# WARNING:root:Type float64 will be converted to 32 bit float and may lose precision.
# [cellxgene] CAUTION: due to the size of your dataset, running differential expression may take longer or fail.
# [cellxgene] Launching! Opening your browser to http://localhost:5005 now.
# [cellxgene] Type CTRL-C at any time to exit.

# %% [markdown]
# ## PF2 PACMAPs

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["leiden"], legend_loc="on data")
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_utils.py:432: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["leiden"])
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["Cell Type Old"])
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["SLE_status"])
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color="Processing_Cohort")
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## Original UMAPs

# %%
sc.pl.umap(
    data,
    color=["Processing_Cohort", "louvain_orig", "SLE_status"],
    legend_loc="on_data",
)
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ...

# %%
sc.pl.umap(data, color=["Processing_Cohort"], legend_loc="on_data")
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(data, color=["CD8|CD8A", "CD4|CD4"], na_color="w")

# %%
sc.pl.umap(data, color=["Cell Type Old"], na_color="w")
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## Marker Genes

# %%
sc.tl.rank_genes_groups(data, "leiden", method="wilcoxon")
sc.pl.rank_genes_groups(data, n_genes=30, sharey=False, save=True)
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# ...

# %%
# B, PB, T4, T8, NK, Prolif, cDC, pDC, Progen, CM, nCM

celltypedict_layer1 = {
    "0": "B",
    "1": "T4",
    "2": "CM",
    "3": "NK",
    "4": "T8",  # Not sure
    "5": "T8",
    "6": "CM",
    "7": "CM",
    "8": "nCM",
    "9": "T4",
    "10": "T4",  # Treg
    "11": "T4",
    "12": "T4",
    "13": "CM",
    "14": "T8",
    "15": "T4",
    "16": "T4",
    "17": "B",  # Treg
    "18": "CM",
    "19": "Prolif",
    "20": "CM",
    "21": "T4",  # not sure
    "22": "T4",  # Questionable
    "23": "B",  # Questionable
    "24": "cDC",
    "25": "T4",
    "26": "Prolif",
    "27": "NK",  # Could be CD8
    "28": "B",
    "29": "T4",  # Treg
    "30": "CM",  # Intermediate
    "31": "CM",  # Questionable
    "32": "T4",
    "33": "PB",  # Neutrophil
    "34": "NK",
    "35": "T8",
    "36": "CM",
    "37": "PB",  # Questionable
    "38": "T4",
    "39": "pDC",
    "40": "CM",
    "41": "T4",
    "42": "B",
    "43": "T4",  # pDC?
    "44": "CM",
    "45": "Prolif",
    "46": "Prolif",
    "47": "pDC",
}

# print(data.obs.leiden.replace(celltypedict_layer1))
data.obs["Cell Type"] = data.obs.leiden.replace(celltypedict_layer1)
# Out:
# /tmp/ipykernel_959565/3075210156.py:54: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   data.obs["Cell Type"] = data.obs.leiden.replace(celltypedict_layer1)

# %%
# sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["Cell Type New", "Cell Type"])
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["Cell Type"])
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Lymphoid Compartment

# %%
data_l = an.read_h5ad("Lupus_Neighbors_10N_3R.h5ad")
data_l.obs["louvain_orig"] = data_l.obs["louvain"]
data_l.obs = data_l.obs.rename(columns={"Cell Type": "Cell Type Old"})
data_l.obs["Cell Type"] = data_l.obs.leiden.replace(celltypedict_layer1)
data_l = data_l[
    data_l.obs["Cell Type"].isin(["T4", "T8", "B", "PB", "NK", "Prolif"]).values, :
]
# Out:
# /tmp/ipykernel_390755/1170905318.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   data_l.obs["Cell Type"] = data_l.obs.leiden.replace(celltypedict_layer1)

# %%
sc.pp.highly_variable_genes(data_l, min_mean=0.0001, max_mean=10, min_disp=0.01)
data_l = data_l[:, data_l.var.highly_variable.values]
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:553: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns["hvg"] = {"flavor": flavor}

# %%
sc.tl.rank_genes_groups(data_l, "leiden", method="wilcoxon")
sc.pl.rank_genes_groups(data_l, n_genes=30, sharey=False, save=True)
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:582: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ...

# %%
celltypedict_layer2 = {
    "0": "B Naive",
    "1": "T4 Naive",
    "2": "CM",  # Leave
    "3": "NK Dim",  # But a lot of NKG7 so maybe not?
    "4": "T8 GZMK",
    "5": "T8 GZMH",
    "6": "CM",  # Leave
    "7": "CM",  # Leave
    "8": "nCM",  # Leave
    "9": "T4 Naive",
    "10": "T4 Naive",  # Treg
    "11": "T4 Naive",
    "12": "T4 EM",  # Check
    "13": "CM",  # Leave
    "14": "T8 Naive",
    "15": "T4 Naive",
    "16": "T4 Naive",
    "17": "B Naive",  # Treg
    "18": "CM",  # Leave
    "19": "Prolif",
    "20": "CM",  # Leave
    "21": "T4 EM",  # Based on interferon response
    "22": "Null",
    "23": "B Naive",  # No CD27
    "24": "cDC",  # Leave
    "25": "T4 Reg",  # Based on interferon response
    "26": "T8 GZMH",
    "27": "NK Dim",
    "28": "B Mem",
    "29": "T4 Reg",  # Treg
    "30": "CM",  # Leave
    "31": "CM",  # Leave
    "32": "T4 Naive",  # Look again
    "33": "B Plasma",
    "34": "NK Bright",
    "35": "T8 GZMH",
    "36": "CM",  # Leave
    "37": "B Plasma",
    "38": "T4 Naive",
    "39": "pDC",
    "40": "CM",  # Leave
    "41": "T4 Naive",
    "42": "B Naive",
    "43": "T4 Naive",  # pDC?
    "44": "CM",
    "45": "Prolif",
    "46": "T8 Naive",  # Not sure
    "47": "pDC",
}

data.obs["Cell Type2"] = data.obs.leiden.replace(celltypedict_layer2)
# Out:
# /tmp/ipykernel_390755/1865573002.py:51: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   data.obs["Cell Type2"] = data.obs.leiden.replace(celltypedict_layer2)

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["Cell Type2"])
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["leiden"], legend_loc="on data")
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Myeloid Compartment

# %%
data_m = an.read_h5ad("Lupus_Neighbors_10N_3R.h5ad")
data_m.obs["louvain_orig"] = data_m.obs["louvain"]
data_m.obs = data_m.obs.rename(columns={"Cell Type": "Cell Type Old"})
data_m.obs["Cell Type"] = data_m.obs.leiden.replace(celltypedict_layer1)
data_m = data[data.obs["Cell Type"].isin(["CM", "nCM", "cDC", "pDC"]).values, :]
# Out:
# /tmp/ipykernel_390755/3908648012.py:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   data_m.obs["Cell Type"] = data_m.obs.leiden.replace(celltypedict_layer1)

# %%
sc.tl.rank_genes_groups(data_m, "leiden", method="wilcoxon")
sc.pl.rank_genes_groups(data_m, n_genes=30, sharey=False, save=True)
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:582: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# WARNING: saving figure to file figures/rank_genes_groups_leiden.pdf

# %%
celltypedict_layer2 = {
    "0": "B Naive",
    "1": "T4 Naive",
    "2": "CM",
    "3": "NK Dim",
    "4": "T8 GZMK",
    "5": "T8 GZMH",
    "6": "CM",
    "7": "cDC1",
    "8": "nCM",
    "9": "T4 Naive",
    "10": "T4 Naive",
    "11": "T4 Naive",
    "12": "T4 EM",
    "13": "CM",
    "14": "T8 Naive",
    "15": "T4 Naive",
    "16": "T4 Naive",
    "17": "B Naive",
    "18": "CM",
    "19": "Prolif",
    "20": "CM",
    "21": "T4 EM",
    "22": "Null",
    "23": "B Naive",
    "24": "cDC2",
    "25": "T4 Reg",
    "26": "T8 GZMH",
    "27": "NK Dim",
    "28": "B Mem",
    "29": "T4 Reg",
    "30": "CM",
    "31": "CM",
    "32": "T4 Naive",
    "33": "B Plasma",
    "34": "NK Bright",
    "35": "T8 GZMH",
    "36": "nCM",
    "37": "B Plasma",
    "38": "T4 Naive",
    "39": "pDC",
    "40": "CM",
    "41": "T4 Naive",
    "42": "B Naive",
    "43": "T4 Naive",
    "44": "CM",
    "45": "Prolif",
    "46": "T8 Naive",
    "47": "pDC",
}


data.obs["Cell Type2"] = data.obs.leiden.replace(celltypedict_layer2)
# Out:
# /tmp/ipykernel_959565/1947409935.py:52: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   data.obs["Cell Type2"] = data.obs.leiden.replace(celltypedict_layer2)

# %%
sc.pl.embedding(data, basis="X_pf2_PaCMAP", color=["Cell Type2"], legend_loc="on data")
# Out:
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/brianoj/.cache/pypoetry/virtualenvs/sccp-rvA4szVo-py3.11/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
print(data)
# Out:
# AnnData object with n_obs × n_vars = 1263673 × 2161
# ...

# %% [markdown]
# ### Save Cell Types

# %%
cellDF = data.obs[["Cell Type", "Cell Type2"]]
cellDF.columns = ["Cell Type", "Cell Type2"]
cellDF.index.name = None
cellDF.to_csv("LupusCellTypesFinal.csv")
data.write_h5ad("Lupus_Annotated_Final_Updated.h5ad")

# %% [markdown]
# ## Marker Genes Storage

# %%
types = {
    "CM": ["CD14LYZ", "S100A8", "S100A9", "IL8"],
    "cDC1": ["LGALGS2", "MS4A6A"],
    "cDC2": ["HLA-DQA1", "HLA-DQA2", "HLA-DMB"],
    "nCM": ["FCGR3A"],
    "pDC": ["SERPINF1", "LILRA", "IRF8"],
    "B Naive": ["TCL1A", "MS4A1"],
    "B Memory": ["BANK1"],
    "B Plasma": ["IGJ", "CD79A", "MZB1"],
    "T4 Naive": ["CCD7", "MAL", "LEF1"],
    "T4 Reg": ["ITGB1"],
    "T4 EM": ["IL7R", "RTKN1"],
    "T8 Naive": ["CD8A", "CD8B"],
    "T8 GZMK": ["GZMK", "GNLY"],
    "T8 GZMH": ["GZMH"],
    "NK Bright": ["GNLY"],
    "NK Dim": ["NKG7"],
    "Prolif": ["STMN1"],
    "Null": ["RGS18"],
}
